# %% [markdown]
# **Basic Pyton**

# %% [markdown]
# #DataTypes in python

# %% [markdown]
# ![image.png](attachment:b412222f-a680-4029-b6c4-8fa6d2f88616.png)

# %% [markdown]
# ![image.png](attachment:b412222f-a680-4029-b6c4-8fa6d2f88616.png)

# %% [markdown]
# #STRINGS = Strings are nothing but charecters which are enclosed with single quate double or thriple quote example "action"
# it mainly used for storing and manupulating names.

# %%
greeting = "Hello World!"
multiline = """This is
a multiline string"""

type(greeting)

print(type(multiline))
# Out:
# "<class 'str'>"

# %%
greetings = "Hello World"
type(greetings)
print(type(greetings))
print (greetings)
# Out:
# <class 'str'>
# Hello World

# %% [markdown]
# **Numeric Data Type**

# %% [markdown]
# here in numeric data type we have total 3 types they are:
# integer(int)
# floating point(float)
# Complex numbers(complex)
# here integer will mainly used for represent for whole numbers

# %%
age= 22
print(type(age))
# Out:
# <class 'int'>

# %%
print (age)
# Out:
# 22

# %%
pivalue=3.14
print(type(pivalue))
age=22
print(type(age))
print(pivalue)
# Out:
# <class 'float'>
# <class 'int'>
# 3.14

# %% [markdown]
# here we can observe that in pivalue we are entering dechimal point which represents float. then it willprint the output.

# %%
complex numbers= here in this we can keep complex numbers like 23+2j which represent both integer and alphabits. here as shown in this code

# %%
a=22+2j
print(a)
a=22+23j
b=23+2j
print(a+b)
# Out:
# (22+2j)
# (45+25j)

# %% [markdown]
# Sequence
# it is nothing but it is an ordered type of collection of data like iteration. it allows multiple items to store in a sequence way
# here in sequence we have 3 types they are:
# List = here list will mainly represents the ordered and mutable means we can change on it
# tuples = where as in tuples are immutable we can change of it.
# range = where as range will represents sequence of numbers.

# %%
flowers = ["rose","lilly","jasmin"]
print(type(flowers))
print (flowers)
# Out:
# "['rose', 'lilly', 'jasmin']"

# %%
numbers = (10,20,30)
print(type(numbers))
# Out:
# "<class 'tuple'>"

# %%
numbers = (2,19,23)
print(type(numbers))
print(numbers)
# Out:
# '(2, 19, 23)'

# %%
numbers = range(10)
print(numbers)
# Out:
# 'range(0, 10)'

# %%
print(type(numbers))
# Out:
# "<class 'range'>"

# %%
numbers = range(5)
print(numbers)
# Out:
# 'range(0, 5)'

# %% [markdown]
# Mapping Type
# Dictionary (dict)
# Unordered, mutable, and stores key-value pairs.

# %%
student= {"name":"dinesh", "age":"22"}
print(type(student))
# Out:
# "<class 'dict'>"

# %%
print (student)
# Out:
# "{'name': 'dinesh', 'age': '22'}"

# %% [markdown]
# Set Types
# Set (set)
# Unordered, mutable, and contains unique elements.
# frozen_set
# immutable contains unique element

# %%
colors={"red","yellow","green"}
print(type(colors))
# Out:
# "<class 'set'>"

# %%
frozen_colors= frozenset(("red","yellow","green"))
print(type(frozen_colors))
# Out:
# "<class 'frozenset'>"

# %%
frozen_colors=frozenset(["red","blue","green"])
print(frozen_colors)
# Out:
# "frozenset({'blue', 'red', 'green'})"

# %%
print(type(frozen_colors))
# Out:
# "<class 'frozenset'>"

# %% [markdown]
# boolen type
# here boolen will mainly represents the data is true or false

# %%
is_pass= True
print(type(is_pass))
# Out:
# "<class 'bool'>"

# %%
print(is_pass)
# Out:
# 'True'

# %%
is_pass= True
or_else= False
print(or_else)
# Out:
# 'False'

# %% [markdown]
# bynari types
# bytes
# Represents an immutable sequence of bytes.
# Each element is a byte (an integer in the range 0-255).
# Often used for binary data, such as files or network protocols.
# it is immutable and supports indexing files

# %%
a= b"hello"
print(type(a))
c= b"hello_world"
print(a+c)
# Out:
# "b'hellohello_world'"

# %% [markdown]
# bytearray is muteable

# %%
data=bytearray(22)
print(data)
# Out:
# "bytearray(b'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00')"

# %% [markdown]
# memoryview= it is used to handle large amount of data without copying it

# %%
mv = memoryview(bytes(3))
print(mv)
# Out:
# '<memory at 0x0000029182E66980>'

# %%
m = mv(bytes(3))
print(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 m = mv(bytes(3))
#       2 print(m)
#
# TypeError: 'memoryview' object is not callable

# %%
m = memoryview(bytes(3))
print(m)
# Out:
# '<memory at 0x0000029182E65900>'

# %%
x = None
print(x)
# Out:
# 'None'

# %%
print(type(x))
# Out:
# "<class 'NoneType'>"
